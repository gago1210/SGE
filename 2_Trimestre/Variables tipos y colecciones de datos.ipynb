# %% [markdown]
# ## VARIABLES Y CONVERSIÓN DE TIPOS

# %%
num = 1234
nombre = "Pedro"
cadena = """
En varias lineas
preformateado
"""
salario = 1000.35
estado = True
lista =("Ana", 100, 12.5, True)
tupla = ['luis', 1000, 'Pedrito']
conjuntos = {}
lista3 = set()

# %%
# COMENTARIO DE LINEA
"""
Comentario 
multilinea

"""

# %%
cadena
# Out:
# '\nEn varias lineas\npreformateado\n'

# %%
type(lista3)
# Out:
# set

# %%
listado = [1,2,3,1,4,5,6,8]

# %%
type(listado)
# Out:
# list

# %%
# Elimina los valores duplicados

elementol = list(set(listado))

# %%
elementol
# Out:
# [1, 2, 3, 4, 5, 6, 8]

# %%
float(num)
# Out:
# 1234.0

# %%
"""
Para convertir datos:

int()
str()
float()
list()
tuple()
set()
dict()

"""

# %%
"""
not False == True

>
<
=
!=

"""

# %%
False !=True

# %%
len(nombre)
# Out:
# 5

# %% [markdown]
# ## CADENAS
# ## Slicing es coger parte de cadenas

# %%
cadena2 = "La vida en Roma es muy alegre"

# %%
cadena2[::-1]
# Out:
# 'ergela yum se amoR ne adiv aL'

# %%
cadena2[-1] # último carácter
# Out:
# 'e'

# %%
print(cadena2[::-1], len(cadena2))
# Out:
# ergela yum se amoR ne adiv aL 29

# %%
capital = cadena2[11:15]

# %%
capital[::-1]
# Out:
# 'amoR'

# %%
capital[2] = "c" # no funciona porque las cadenas son inmutables
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 capital[2] = "c"
#
# TypeError: 'str' object does not support item assignment

# %%
nombres = ["david", "pedro", "andrés"]

# %%
nombres[-1]
# Out:
# 'andrés'

# %%
nombres[-1][2:4]
# Out:
# 'dr'

# %%
"Comodo"[:3] + "i" + "lado"[2:]
# Out:
# 'Comido'

# %%
cadena2.split(" ")
# Out:
# ['La', 'vida', 'en', 'Roma', 'es', 'muy', 'alegre']

# %%
cadena2.split(" ")[0:3]
# Out:
# ['La', 'vida', 'en']

# %%
lista = cadena2.split(" ")

# %%
lista
# Out:
# ['La', 'vida', 'en', 'Roma', 'es', 'muy', 'alegre']

# %%
for palabra in lista:
    print(palabra.upper())
    print(palabra.lower())
# Out:
# LA
# la
# VIDA
# vida
# EN
# en
# ROMA
# roma
# ES
# es
# MUY
# muy
# ALEGRE
# alegre

# %% [markdown]
# ## TUPLAS
# ### Inmutables

# %%
tupla = ("Paco", 10, [10,12,34], "Enero", -90,10)

# %%
tupla[0] = "Francisco"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 tupla[0] = "Francisco"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tupla[2][1] = 20

# %%
tupla
# Out:
# ('Paco', 10, [10, 20, 34], 'Enero', -90, 10)

# %%
nombre = "Comando"
codigo = 102
mes = "Abril"
configuracion = (nombre,codigo,mes)

# %%
configuracion
# Out:
# ('Comando', 102, 'Abril')

# %%
print("Los valores de la tupla son {0}: {1}, {2} y {3}".format(len(configuracion), configuracion[0], configuracion[1], configuracion[2]))
# Out:
# Los valores de la tupla son 3: Comando, 102 y Abril

# %%
configuracion.index("Abril")
# Out:
# 2

# %%
configuracion.append("pepe")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 configuracion.append("pepe")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# ## LISTAS

# %%
lista = ["Pepe", 100,-15,"Felipe",1000.20]

# %%
lista.append("Luisete")

# %%
lista
# Out:
# ['Pepe', 100, -15, 'Felipe', 1000.2, 'Luisete']

# %%
datosvalidos = lista[:4]

# %%
lista
# Out:
# ['Pepe', 100, -15, 'Felipe', 1000.2, 'Luisete']

# %%
datosvalidos
# Out:
# ['Pepe', 100, -15, 'Felipe']

# %%
a = [10,20,30]
b = [40,50,60]
c = [70,80,90]

# %%
datos = [a,b,c]

# %%
datos
# Out:
# [[10, 20, 30], [40, 50, 60], [70, 80, 90]]

# %%
datos[1][1]
# Out:
# 50

# %%
datos[::-1]
# Out:
# [[70, 80, 90], [40, 50, 60], [10, 20, 30]]

# %%
datosfinales = [datos[2][::-1], datos[1][::-1], datos[0][::-1]]

# %%
datosfinales
# Out:
# [[90, 80, 70], [60, 50, 40], [30, 20, 10]]

# %% [markdown]
# ## CONJUNTOS

# %%
conjunto = {8,9,10}

# %%
type(conjunto)
# Out:
# set

# %%
con = set() # para hacer un conjunto vacío

# %%
type(con)
# Out:
# set

# %%
conjunto.add(11)

# %%
conjunto
# Out:
# {8, 9, 10, 11}

# %%
conjunto.add("Pedro")

# %%
list(conjunto)
# Out:
# [8, 9, 10, 11, 'Pedro', 'Luis']

# %%
gente = {"Luis", "Ana", "Pedro", "Andrea","Luis", "Ana","Maria"}

# %%
gente.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 gente.sort()
#
# AttributeError: 'set' object has no attribute 'sort'

# %%
list(gente).sort()

# %%
gente
# Out:
# {'Ana', 'Andrea', 'Luis', 'Maria', 'Pedro'}

# %%
"Pedro" in gente
# Out:
# True

# %%
"Pepe" in gente
# Out:
# False

# %%
frase = "De perdidos al río"

# %%
set(frase)
# Out:
# {' ', 'D', 'a', 'd', 'e', 'i', 'l', 'o', 'p', 'r', 's', 'í'}

# %%
num = {1,2,3,10,12,20}
lis = {"1", "10", "100", 300, 8}

# %%
for ele in lis:
    num.add(int(ele))

# %%
num
# Out:
# {1, 2, 3, 8, 10, 12, 20, 100, 300}

# %%
personas = {'Nombre':'Pamela', 'Edad':25,'Ciudad':'Madrid'}

# %%
type(personas)
# Out:
# dict

# %%
personas['Nombre']+ ' ' + str(personas['Edad'])
# Out:
# 'Pamela 25'

# %%
print(personas['Nombre'],personas['Edad'])
# Out:
# Pamela 25

# %%
personas
# Out:
# {'Nombre': 'Pamela', 'Edad': 25, 'Ciudad': 'Madrid'}

# %%
personas['Edad']+=10

# %%
personas
# Out:
# {'Nombre': 'Pamela', 'Edad': 35, 'Ciudad': 'Madrid'}

# %%
edadesG= {'Profesores':45, 'Alumnos':22}

# %%
(edadesG['Profesores']+ edadesG['Alumnos'])/2 # calcula la media de edad
# Out:
# 33.5

# %%
for grupo in edadesG:
    print(grupo, edadesG[grupo])
# Out:
# Profesores 45
# Alumnos 22

# %%
listadoClase = []

# %%
listadoClase.append({'Nombre':'Pedro', 'Edad':34})

# %%
listadoClase
# Out:
# [{'Nombre': 'Pedro', 'Edad': 34}]

# %%
listadoClase.append({'Nombre':'Carlos', 'Edad':28})

# %%
listadoClase
# Out:
# [{'Nombre': 'Pedro', 'Edad': 34}, {'Nombre': 'Carlos', 'Edad': 28}]

# %%
listadoClase.append({'Nombre':str(input('Nombre     ')), 'Edad':int(input("Edad    "))})
# Out:
# Nombre      Maria
# Edad     37

# %%
listadoClase
# Out:
# [{'Nombre': 'Pedro', 'Edad': 34},
#  {'Nombre': 'Carlos', 'Edad': 28},
#  {'Nombre': 'Maria', 'Edad': 37}]

# %%
for n in range(0, len(listadoClase)):
    print(listadoClase[n]['Nombre'],listadoClase[n]['Edad'])
# Out:
# Pedro 34
# Carlos 28
# Maria 37

# %% [markdown]
# ## PILAS (last in first out)

# %%
pila = [3,4,5]

# %%
pila.append(7)

# %%
pila
# Out:
# [3, 4, 5, 6, 7]

# %%
pila.pop() # para sacar el último elemento
# Out:
# 7

# %%
pila
# Out:
# [3, 4, 5, 6]

# %% [markdown]
# ### COLAS (first in first out)

# %%
from collections import deque

# %%
cola = deque(['Pepe', 'Luis','Ana'])

# %%
cola
# Out:
# deque(['Pepe', 'Luis', 'Ana'])

# %%
cola.append('Andrea')

# %%
cola
# Out:
# deque(['Pepe', 'Luis', 'Ana', 'Andrea', 'Andrea'])

# %%
cola.popleft()
# Out:
# 'Pepe'
